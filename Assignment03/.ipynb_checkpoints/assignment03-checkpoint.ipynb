# %% [markdown]
# ## Assignment03
#
# ### StudentID : 20155212
#
# ### Name : Choi Bowon
#
# ### GitHub : https://github.com/ChoiBowon/Assignment

# %%
import numpy as np
import matplotlib.pyplot as plt
import random

# %%
k = int(input("Input k number : "))
Xarr_cluster = []
Yarr_cluster = []
cluster = []
point = []
label = []
# Out:
# Input k number : 3

# %%
class k_Point:
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    def setPoint(self,x,y):
        self.x = x
        self.y = y

# %%
class Cluster:
    def __init__(self,x,y,label):
        self.x = x
        self.y = y
        self.label = label
        
    def setLabel(self,label):
        self.label = label

# %%
def generatePointCluster():
    for i in range(k):
        point.append(k_Point(float(format(random.random(),".2f")), float(format(random.random(),".2f"))))
    for j in range(100):
        cluster.append(Cluster(float(format(random.random(),".2f")), float(format(random.random(),".2f")),0))
        print(cluster[j].x, cluster[j].y, cluster[j].label)

# %%
def computeDistance(points,clusters):
    d = np.zeros((100, k))
    for i in range(100):
        for j in range(k):
            d[i][j] = format(((clusters[i].x - points[j].x)**2 + (clusters[i].y - points[j].y)**2)**0.5,".2f")

    return d

# %%
def initialiseLabel():
    for i in range(100):
        cluster[i].setLabel(random.randrange(0,k))
        print("label:", cluster[i].label)
        
    return label

# %%
def computeCentroid():
    x_temp = np.zeros(k)
    y_temp = np.zeros(k)
    nums = np.zeros(k)
    for i in range(100):
        x_temp[cluster[i].label] += cluster[i].x
        y_temp[cluster[i].label] += cluster[i].y
        nums[cluster[i].label] += 1
        
    for i in range(k):
        point[i].setPoint((x_temp[i]/nums[i]), (y_temp[i]/nums[i]))
        print("centroid:", point[i].x, point[i].y)

# %%
def assignLabel():
    d = computeDistance(point,cluster)
    Min = 1
    index = 0
    
    for i in range(100):
        Min = 1
        for j in range(k):
            if Min > d[i][j]:
                Min = d[i][j]
                index = j
        cluster[i].setLabel(index)

# %%
def computeEnergy():
    energy = 0
    for i in range(100):
        energy += ((cluster[i].x - point[cluster[i].label].x)**2 + ((cluster[i].y - point[cluster[i].label].y))**2)**0.5
    energy /= 100    
    print("energy:",energy)

# %%
FormalEnergy = 1
CurrentEnergy = 0

generatePointCluster()
initialiseLabel()

while(FormalEnergy != CurrentEnergy):
    computeCentroid()
    FormalEnergy = CurrentEnergy;
    CurrentEnergy = computeEnergy()
    assignLabel()
# Out:
# 0.38 0.62
# 0.3 0.66
# 0.77 0.77
# ------------------------------
# 0.66 0.39 0
# 1.0 0.18 0
# 0.93 0.43 0
# 0.43 0.28 0
# 0.21 0.06 0
# 0.16 0.6 0
# 0.43 0.97 0
# 0.52 0.68 0
# 0.71 0.55 0
# 0.6 0.73 0
# 0.42 0.01 0
# 0.33 0.46 0
# 0.04 0.61 0
# 0.04 0.01 0
# 0.76 0.33 0
# 0.06 0.42 0
# 0.86 0.01 0
